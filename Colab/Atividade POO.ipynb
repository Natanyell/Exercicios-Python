# %%
#3
def sum(num1, num2):
    return num1 + num2
    
print("\tSoma de dois números\n")
num1 = int(input("Digite um número: "))
num2 = int(input("Digite outro número: "))

print ("")
print ("O resultado da soma é %d" %sum(num1, num2))
# Out:
# 	Soma de dois números
#
# Digite um número: 12
# Digite outro número: 12
#
# O resultado da soma é 24

# %%
#4
alguma_coisa = input('Digite algo: ')

print('O tipo primitivo  é: {} '.format(type(alguma_coisa)))

print('Só tem espaço? {}'.format(alguma_coisa.isspace()))
print(' É um número? {}'.format(alguma_coisa.isnumeric()))
print('É alfabético? {}'.format(alguma_coisa.isalpha()))
print('É alfanumérico? {}'.format(alguma_coisa.isalnum()))
print('Está em maiúsculas? {}'.format(alguma_coisa.isupper()))
print('Está em minúsculas? {}'.format(alguma_coisa.islower()))
print('Está capitalizado? {}'.format(alguma_coisa.istitle()))
print('A string está vazia ?',alguma_coisa.isprintable())
# Out:
# Digite algo: 12345678
# O tipo primitivo  é: <class 'str'>
# Só tem espaço? False
#  É um número? True
# É alfabético? False
# É alfanumérico? True
# Está em maiúsculas? False
# Está em minúsculas? False
# Está capitalizado? False
# A string está vazia ? True

# %%
#5
num = int(input('Digite um numero para ver o seu sucessor e antecessor: '))

sucessor = num + 1
antecessor = num - 1

print('O sucessor de %d é %d' %(num,sucessor))
print('O antecessor de %d é %d' %(num,antecessor))
# Out:
# Digite um numero para ver o seu sucessor e antecessor: 109
# O sucessor de 109 é 110
# O antecessor de 109 é 108

# %%
#6
n1 = int(input('Digite um numero: '))

dobro = n1 * 2
triplo = n1 * 3
raiz = n1 ** (1/2)

print('O numero digitado é {} \ndobro: {} \ntriplo: {} \nraiz: {:.2f} '.format(n1,dobro,triplo,raiz))
# Out:
# Digite um numero: 5
# O numero digitado é 5
# dobro: 10
# triplo: 15
# raiz: 2.24

# %%
#7
n1 = float(input('Digite um numero: '))
n2 = float(input('Digite outro numero: '))

media = (n1+n2) / 2

print(f'A sua media é de {media} ')

if media < 6:
    print('Você está de EXAME')
else:
    print('Você passou !')
# Out:
# Digite um numero: 12
# Digite outro numero: 15
# A sua media é de 13.5
# Você passou !

# %%
#8
metros = float(input('Digite um valor em metros para ser convertido: '))

centimetros = metros * 100
milimetros = metros * 1000

print('O valor {}m em cm é {} e em milimetros é {}'.format(metros,centimetros,milimetros))
# Out:
# Digite um valor em metros para ser convertido: 2
# O valor 2.0m em cm é 200.0 e em milimetros é 2000.0

# %%
#9
num = int(input('Digite um numero para ver a sua tabuada: '))

print(num, 'x 0  = ', num * 0)
print(num, 'x 1  = ',num * 1)
print(num, 'x 2  = ',num * 2)
print(num, 'x 3  = ',num * 3)
print(num, 'x 4  = ',num * 4)
print(num, 'x 5  = ',num * 5)
print(num, 'x 6  = ',num * 6)
print(num, 'x 7  = ',num * 7)
print(num, 'x 8  = ',num * 8)
print(num, 'x 9  = ',num * 9)
print(num, 'x 10  = ',num * 10)
# Out:
# Digite um numero para ver a sua tabuada: 10
# 10 x 0  =  0
# 10 x 1  =  10
# 10 x 2  =  20
# 10 x 3  =  30
# 10 x 4  =  40
# 10 x 5  =  50
# 10 x 6  =  60
# 10 x 7  =  70
# 10 x 8  =  80
# 10 x 9  =  90
# 10 x 10  =  100

# %%
#10
money = float(input('Quanto dinheiro vc tem na carteira? '))

#1 dolar == 3. reais

conversao_dolar = money / 3.37 #convertendo para dolar
conversao_euro = money / 4.45 #convetrendo para euro
conversao_iene = money / 0.035 #convertendo para iene


print('Com {} reais voce consegue comprar {} dolares'.format(money,conversao_dolar))
print('\n')
print('Com {} reais voce pode comprar {} euros'.format(money,conversao_euro))
print('\n')
print('Com {} reais voce pode comprar {} ienes'.format(money,conversao_iene))

# %%
#11
altura = float(input('Digite a alturada parede: '))

largura = float(input('Digite a largura da parede: '))

area = altura * largura

tinta = area / 2

print('Para pintar uma area de {} é necessario {} litros de tinta'.format(area,tinta))
# Out:
# Digite a alturada parede: 5
# Digite a largura da parede: 15
# Para pintar uma area de 75.0 é necessario 37.5 litros de tinta

# %%
#12
produto1 = float(input('Digite o preço do produto 1: '))
produto2 = float(input('Digite o preço do produto 2: '))
produto3 = float(input('Digite o preço do produto 3: '))


desconto1 = produto1 * 0.05
valor1 = produto1 - desconto1
print('Valor do produto 1 com desconto {} '.format(valor1))

desconto2 = produto2 * 0.10
valor2 = produto2 - desconto2
print('Valor do produto 2 com desconto {} '.format(valor2))

desconto3 = produto3 * 0.15
valor3 = produto3 - desconto3
print('Valor do produto 3 com desconto {} '.format(valor3))

# %%
#13
salario = float(input('Digite o seu salario: '))


aumento = salario + (salario * 0.15)

print('Seu salario com 15% de aumento passe a ser {} reais'.format(aumento))
# Out:
# Digite o seu salario: 1200.30
# Seu salario com 15% de aumento passe a ser 1380.345 reais

# %%
#14
C = float(input("Digite a temperatura em °C: "))
F = (9 * C / 5) + 32
print("%5.2f°C é igual a %5.2f°F" % (C, F))
# Out:
# Digite a temperatura em °C:24
# 24.00°C é igual a 75.20°F

# %%
#15
km = float(input('Quantos km foram percorridos: '))
dias = int(input('Quantos dias foram o aluguel: '))
valorKmPercorrido = km * 0.15
valorDiaAluguel = 60 * dias

print(f' O valor total foi R${valorKmPercorrido + valorDiaAluguel}, sendo R${valorKmPercorrido} ao km percorrido e R${valorDiaAluguel} aos dias de aluguel')
# Out:
# Quantos km foram percorridos: 26
# Quantos dias foram o aluguel: 45
#  O valor total foi R$2703.9, sendo R$3.9 ao km percorrido e R$2700 aos dias de aluguel

# %%
#16
num = float(input('digite um número: '))
print('o valor digitado foi {} e a sua porção inteira é {}'.format(num, int(num)))
# Out:
# digite um número: 14.5
# o valor digitado foi 14.5 e a sua porção inteira é 14

# %%
#17
from math import hypot

co = float(input('Comprimento do cateto oposto :'))
ca = float(input('Comprimento do cateto adjacente: '))
hi = hypot(co, ca)

print('A hipotenusa vai medir {:.2f}'.format(hi))
# Out:
# Comprimento do cateto oposto :77
# Comprimento do cateto adjacente: 76
# A hipotenusa vai medir 108.19

# %%
#18
from math import sin, cos, tan, radians

ang = float(input("Digite um ângulo de uma circunferência (ou seja, entre 0º e 360º): \n"))

seno = sin(radians(ang))
coss = cos(radians(ang))
tang = tan(radians(ang))

print("O ângulo de {} tem o seno de {:.2f}.".format(ang, seno))
print("O ângulo de {} tem o cosseno de {:.2f}.".format(ang, coss))
print("O ângulo de {} tem a tangente de {:.2f}.".format(ang, tang))
# Out:
# Digite um ângulo de uma circunferência (ou seja, entre 0º e 360º):
# 180
# O ângulo de 180.0 tem o seno de 0.00.
# O ângulo de 180.0 tem o cosseno de -1.00.
# O ângulo de 180.0 tem a tangente de -0.00.

# %%
#19
from random import choice
a1 = input('Nome da(o) primeira(o) aluna(o): ')
a2 = input('Nome da(o) segunda(o) aluna(o): ')
a3 = input('Nome da(o) terceira(o) aluna(o); ')
a4 = input('Nome da(o) quarta(o) aluna(o): ')
lista = [a1, a2, a3, a4]
#escolhida = random.choice(lista)
escolhida = choice(lista)
print('A aluna sorteada foi {}!'.format(escolhida))
# Out:
# Nome da(o) primeira(o) aluna(o): Aline
# Nome da(o) segunda(o) aluna(o): Pedro
# Nome da(o) terceira(o) aluna(o); Angela
# Nome da(o) quarta(o) aluna(o): Nathan
# A aluna sorteada foi Pedro !

# %%
#20
import random

nome1 = str(input('  Digite o primeiro nome:     '))
nome2 = str(input('  Digiteo segundo nome:     '))
nome3 = str(input('  Digite o terceiro nome:     '))
nome4 = str(input('  Digite o quarto nome:     '))

lista = [nome1,nome2,nome3,nome4]

random.shuffle(lista)#shuffle significa embaralhar algo

print(lista)
# Out:
#   Digite o primeiro nome:     Kia
#   Digiteo segundo nome:     Jurema
#   Digite o terceiro nome:     Eddy
#   Digite o quarto nome:     Natan
# ['Jurema ', 'Kia', 'Eddy', 'Natan']

# %%
#21
'''import pygame
pygame.init()
pygame.mixer.music.load('ex022.mp3')
pygame.mixer.music.play()
pygame.event.wait()'''
# Out:
# "import pygame\npygame.init()\npygame.mixer.music.load('ex022.mp3')\npygame.mixer.music.play()\npygame.event.wait()"

# %%
#22
nome = str(input('Digite o seu nome completo: '))
tamanho = nome.split()

print('Nome com letras maiusculas: {}'.format(nome.upper()))
print('Nome com letras minusculas: {}'.format(nome.lower()))

print(f'O seu nome tem ao todo {len(nome.strip())} letras')

print(f'O seu primeiro nome tem {len(tamanho[0])} letras')
# Out:
# Digite o seu nome completo: natanyell roao rodrigues]
# Nome com letras maiusculas: NATANYELL ROAO RODRIGUES]
# Nome com letras minusculas: natanyell roao rodrigues]
# O seu nome tem ao todo 25 letras
# O seu primeiro nome tem 9 letras

# %%
#23
num = int(input("Digite um número a ser fatiado: \n"))

u = num // 1 % 10
d = num // 10 % 10
c = num // 100 % 10
m = num // 1000 % 10

print("Unidade: {}".format(u))
print("Dezena: {}".format(d))
print("Centena: {}".format(c))
print("Milhar: {}".format(m))
# Out:
# Digite um número a ser fatiado:
# 1236
# Unidade: 6
# Dezena: 3
# Centena: 2
# Milhar: 1

# %%
#24
cid = str(input('Em que cidade você nasceu? ')).strip()
print(cid[:5].upper() == 'SANTO')

# %%
#25
nome = str(input('Digite o seu nome: ')).lower().title().strip()

print('Silva' in nome)
# Out:
# Digite o seu nome: Mucilon
# False

# %%
#26
frase = str(input('\nDigite uma frase: ')).strip().lower()

#print('\nQuantidade de vezes que a letra ''A'' aparece: {}'.format(frase.count('A')))
print('\nQuantidade de vezes que a letra ''a'' aparece: {}'.format(frase.count('a')))

#print('\nEm que posição o A aparece a primeira vez: {}'.format(frase.find('A')))
print('Em que posição o a aparece a primeira vez: {}'.format(frase.find('a')+1))

#print('\nEm que posição o A aparece pela ultima vez: {}'.format(frase.rfind('A')))
print('Em que posição o a aparece pela ultima vez: {}'.format(frase.rfind('a')+1))
# Out:
# Digite uma frase: eu gosto de vocÊ
#
# Quantidade de vezes que a letra a aparece: 0
# Em que posição o a aparece a primeira vez: 0
# Em que posição o a aparece pela ultima vez: 0

# %%
#27
nome = str(input('Digite seu nome inteiro: ')).strip()
inteiro = nome.split()
print('Seu primeiro nome é {} '.format(inteiro[0]))
print('Seu último nome é {}'.format(inteiro[len(inteiro)-1]))
# Out:
# Digite seu nome inteiro: natanyel romão
# Seu primeiro nome é natanyel
# Seu último nome é romão

# %%
#28
from random import randint
# Sorteia o número
numero = randint(0,5)
print('')
print('Vou sortear um número de 0 a 5.')
print('')
usuario = int(input('Qual será o número?: '))

if usuario == numero:
    print('Parabéns você acertou!')
else:
    print('Você errou! O número era {}.'.format(numero))
# Out:
# Vou sortear um número de 0 a 5.
#
# Qual será o número?: 3
# Parabéns você acertou!

# %%
#29
velocidade = float(input('Informe a velocidade do carro: '))

if velocidade > 80:
    print('Você foi multado! O limite é de 80KM/h')

    multa = (velocidade - 80) * 7
    print('A multa custara R${:.2f}'.format(multa))
else:
    print('Não ultrapasse a velocidade permitida!')
# Out:
# Informe a velocidade do carro: 50
# Não ultrapasse a velocidade permitida!

# %%
#30
numero = float(input('Digite um número para saber se é par ou impar:'))
resto = numero % 2

if resto == 0:
    print('Número é par')
else:
    print('Número é impar')

# %%
#31
while True:
	distancia = int(input('Distância que deseja percorrer: '))
	valor1 = 0.45
	valor2 = 0.50

	if distancia > 200:
		passagem = distancia * valor1
		valor = valor1
	else:
		passagem = distancia * valor2
		valor = valor2

	input('Valor por km: R$%.2f / Valor da passagem: R$%.2f\n' % (valor, passagem))

# %%
#32
ano = int(input('Digite o ano: '))
if ano % 100 != 0 and ano % 4 == 0 or ano % 400 == 0:
  print('É um ano bissexto')
else:
  print('Não é bissexto')
# Out:
# Digite o ano: 2022
# Não é bissexto

# %%
#33
a = int(input("Digite o primeiro valor:"))
b = int(input("Digite o segundo valor:"))
c = int(input("Digite o terceiro valor:"))
maior = a
if b > a and b > c:
    maior = b
if c > a and c > b:
    maior = c
menor = a
if b < c and b < a:
    menor = b
if c < b and c < a:
    menor = c
print(f"O menor número digitado foi {menor}")
print(f"O maior número digitado foi {maior}")
# Out:
# Digite o primeiro valor:12
# Digite o segundo valor:5
# Digite o terceiro valor:35
# O menor número digitado foi 5
# O maior número digitado foi 35

# %%
#34
salario = float(input('Digite o seu salario: '))

if salario > 1250:
    superior = salario + (salario * 10 / 100)
    print(f'Você teve um aumento de 10%. Novo Salario R$ {superior:.2f}')

elif salario <= 1250:
    inferior = salario + (salario * 15 / 100)
    print(f'Você teve um aumento de 15%. Novo Salario R$ {inferior:.2f}')
# Out:
# Digite o seu salario: 1350.55
# Você teve um aumento de 10%. Novo Salario R$ 1485.61

# %%
#35
med1 = float(input('Digite a primeira medida: '))
med2 = float(input('Digite a segunda medida: '))
med3 = float(input('Digite a terceira medida: '))

if med1 < med2 + med3 and med2 < med1 + med3 and med3 < med1 + med2:
    print('É um triangulo')
else:
    print('Não é um triangulo')
# Out:
# Digite a primeira medida: 5
# Digite a segunda medida: 9
# Digite a terceira medida: 5.6
# É um triangulo
