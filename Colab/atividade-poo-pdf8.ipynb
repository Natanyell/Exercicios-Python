# %%
class Conta:
    
    def __init__(self, numero, titular, saldo, limite):
        self.numero = numero
        self.titular = titular
        self.saldo = saldo
        self.limite = limite

    def deposita(self, valor):
        self.saldo += valor

    def saca(self, valor):
        if (self.saldo < valor):
            return False
        else:
            self.saldo -= valor
            return True

    def extrato(self):
        print("numero: {}\nsaldo: {}".format(self.numero, self.saldo))


conta = Conta(123-7, "João", 509.0, 1000.0)
conta.extrato()

conta.deposita(50.0)
conta.extrato()

conta.saca(100.0)
conta.extrato()
# Out:
# numero: 116
# saldo: 509.0
# numero: 116
# saldo: 559.0
# numero: 116
# saldo: 459.0
